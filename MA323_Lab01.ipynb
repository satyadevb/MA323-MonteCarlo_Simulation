# %% [markdown]
# <a href="https://colab.research.google.com/github/satyadevb/MA323/blob/main/MA323_Lab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 6; b = 0; m = 11
for xo in range(0,11):
  x = xo;ulist = [xo/m];y = -1;
  while(y != xo):
    y = (a*x + b)%m
    x = y
    ulist.append(y/m)
  del ulist[len(ulist) - 1]
  print(ulist)

a = 3; b = 0; m = 11
for xo in range(0,11):
  x = xo;ulist = [xo/m];y = -1
  while(y != xo):
    y = (a*x + b)%m
    x = y
    ulist.append(y/m)
  del ulist[len(ulist) - 1]
  print(ulist)
# Out:
# [0.0]
# [0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182]
# [0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365]
# [0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454]
# [0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273]
# [0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091]
# [0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091]
# [0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727]
# [0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182, 0.9090909090909091, 0.45454545454545453]
# [0.8181818181818182, 0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364]
# [0.9090909090909091, 0.45454545454545453, 0.7272727272727273, 0.36363636363636365, 0.18181818181818182, 0.09090909090909091, 0.5454545454545454, 0.2727272727272727, 0.6363636363636364, 0.8181818181818182]
# [0.0]
# [0.09090909090909091, 0.2727272727272727, 0.8181818181818182, 0.45454545454545453, 0.36363636363636365]
# [0.18181818181818182, 0.5454545454545454, 0.6363636363636364, 0.9090909090909091, 0.7272727272727273]
# [0.2727272727272727, 0.8181818181818182, 0.45454545454545453, 0.36363636363636365, 0.09090909090909091]
# [0.36363636363636365, 0.09090909090909091, 0.2727272727272727, 0.8181818181818182, 0.45454545454545453]
# [0.45454545454545453, 0.36363636363636365, 0.09090909090909091, 0.2727272727272727, 0.8181818181818182]
# [0.5454545454545454, 0.6363636363636364, 0.9090909090909091, 0.7272727272727273, 0.18181818181818182]
# [0.6363636363636364, 0.9090909090909091, 0.7272727272727273, 0.18181818181818182, 0.5454545454545454]
# [0.7272727272727273, 0.18181818181818182, 0.5454545454545454, 0.6363636363636364, 0.9090909090909091]
# [0.8181818181818182, 0.45454545454545453, 0.36363636363636365, 0.09090909090909091, 0.2727272727272727]
# [0.9090909090909091, 0.7272727272727273, 0.18181818181818182, 0.5454545454545454, 0.6363636363636364]

# %%
import matplotlib.pyplot as plt
import math

def LCG(a,b,m,seed):
  x = seed;y = 0;ulist = [x/m];freq = []
  for i in range(0,20):
    freq.append(0)
  while(y != seed):
    y = (a*x + b)%m
    x = y
    ulist.append(y/m)
    freq[math.floor(20 * y/m)] = 1 + freq[math.floor(20 * y/m)]
  print("Starting value of x is",xo)
  print("Frequency Array :");print(freq)
  plt.hist(ulist,bins = 20,rwidth = 0.75)
  print("Frequency Histogram : ")
  plt.show()

m = 244944;a = 1597;b = 20
arr = [1,29,391,15243,200001]
print("For a =",a,",b =",b,",m =",m)
for xo in arr:
  LCG(a,b,m,xo)
a = 51749
print("For a =",a,",b =",b,",m =",m)
for xo in arr:
  LCG(a,b,m,xo)
# Out:
# For a = 1597 ,b = 20 ,m = 244944
# Starting value of x is 1
# Frequency Array :
# [766, 765, 766, 765, 766, 765, 766, 765, 765, 766, 765, 766, 765, 766, 765, 766, 765, 766, 765, 765]
# Frequency Histogram :
# Starting value of x is 29
# Frequency Array :
# [765, 766, 765, 765, 766, 765, 766, 765, 766, 765, 766, 765, 766, 765, 765, 766, 765, 766, 765, 766]
# Frequency Histogram :
# Starting value of x is 391
# Frequency Array :
# [1531, 1530, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1530, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531]
# Frequency Histogram :
# Starting value of x is 15243
# Frequency Array :
# [1531, 1531, 1531, 1531, 1531, 1531, 1530, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1531, 1530, 1531, 1531, 1531]
# Frequency Histogram :
# Starting value of x is 200001
# Frequency Array :
# [766, 765, 766, 765, 766, 765, 766, 765, 765, 766, 765, 766, 765, 766, 765, 766, 765, 766, 765, 765]
# Frequency Histogram :
# For a = 51749 ,b = 20 ,m = 244944
# Starting value of x is 1
# Frequency Array :
# [1, 3, 3, 3, 3, 3, 3, 2, 4, 0, 4, 2, 3, 3, 3, 3, 3, 3, 2, 3]
# Frequency Histogram :
# Starting value of x is 29
# Frequency Array :
# [25, 24, 24, 25, 24, 25, 24, 25, 24, 24, 24, 24, 24, 24, 24, 24, 25, 24, 25, 24]
# Frequency Histogram :
# Starting value of x is 391
# Frequency Array :
# [8, 8, 9, 8, 7, 9, 9, 6, 9, 9, 6, 9, 9, 7, 8, 9, 8, 8, 8, 8]
# Frequency Histogram :
# Starting value of x is 15243
# Frequency Array :
# [25, 24, 24, 24, 24, 24, 24, 24, 25, 25, 24, 25, 24, 24, 24, 24, 24, 25, 25, 24]
# Frequency Histogram :
# Starting value of x is 200001
# Frequency Array :
# [26, 24, 25, 24, 24, 24, 24, 24, 24, 24, 24, 25, 25, 25, 24, 24, 24, 24, 24, 24]
# Frequency Histogram :

# %%
import matplotlib.pyplot as plt
a = 1229; b = 1; m = 2048;x = 1;y = 0;ulist = [1/m];vlist = [] 
while(y != 1):
  y = (a*x + b)%m
  x = y
  ulist.append(y/m)
  vlist.append(y/m)
del ulist[len(ulist) - 1]
plt.scatter(ulist,vlist)
plt.axis([0, 1, 0, 1])
plt.show()
