# %% [markdown]
# <a href="https://colab.research.google.com/github/satyadevb/MA323/blob/main/MA323_Lab10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import statistics
import random
import math
import time
 
M_list = [100,1000,10000,100000]

print("Without using Antithetic variables:\n")

lengths1 = []

for M in M_list:
    print("\nSample size is ",M,"\n")
    U_list = []
    for i in range(M):
        U = np.random.uniform(0,1)
        U_list.append(math.exp(math.sqrt(U)))
    mean = statistics.mean(U_list)
    variance = statistics.variance(U_list)
    print("Mean of the sample is ",mean,"\n")
    print("Variance of the sample is ",variance,"\n")
    print("The 95% confidence interval is [",mean - 1.96 * math.sqrt(variance/M),",",mean + 1.96 * math.sqrt(variance/M),"]\n")
    lengths1.append(2*1.96*math.sqrt(variance/M))

print("\n\nWith using Antithetic variables:\n")

lengths2 = []

for M in M_list:
    print("\nSample size is ",M,"\n")
    U_list = []
    for i in range(M):
        U = np.random.uniform(0,1)
        U_list.append((math.exp(math.sqrt(U)) + math.exp(math.sqrt(1-U)))/2)
    mean = statistics.mean(U_list)
    variance = statistics.variance(U_list)
    print("Mean of the sample is ",mean,"\n")
    print("Variance of the sample is ",variance,"\n")
    print("The 95% confidence interval is [",mean - 1.96 * math.sqrt(variance/M),",",mean + 1.96 * math.sqrt(variance/M),"]\n")
    lengths2.append(2*1.96*math.sqrt(variance/M))

print("\nRatios of the lengths for the 95% confidence intervals are\n")
for i in range(4):
    print("For sample size = ",10 ** (2 + i),"the ratio is",lengths1[i]/lengths2[i],"\n")
# Out:
# Without using Antithetic variables:
#
#
# Sample size is  100
#
# Mean of the sample is  2.0872258940833435
#
# Variance of the sample is  0.150460806807895
#
# The 95% confidence interval is [ 2.011198909700612 , 2.163252878466075 ]
#
#
# Sample size is  1000
#
# Mean of the sample is  2.0123121160434594
#
# Variance of the sample is  0.19195048727824326
#
# The 95% confidence interval is [ 1.9851570614140153 , 2.0394671706729035 ]
#
#
# Sample size is  10000
#
# Mean of the sample is  1.999482454000526
#
# Variance of the sample is  0.19677673775015597
#
# The 95% confidence interval is [ 1.9907879872788634 , 2.008176920722189 ]
#
#
# Sample size is  100000
#
# Mean of the sample is  1.9993937920730322
#
# Variance of the sample is  0.19471404610110588
#
# The 95% confidence interval is [ 1.9966588085639376 , 2.002128775582127 ]
#
#
#
# With using Antithetic variables:
#
#
# Sample size is  100
#
# Mean of the sample is  2.0035389770128424
#
# Variance of the sample is  0.0008515858810915544
#
# The 95% confidence interval is [ 1.9978193159033 , 2.009258638122385 ]
#
#
# Sample size is  1000
#
# Mean of the sample is  1.999797521503077
#
# Variance of the sample is  0.00105164546560526
#
# The 95% confidence interval is [ 1.9977875460752 , 2.001807496930954 ]
#
#
# Sample size is  10000
#
# Mean of the sample is  2.000178984074703
#
# Variance of the sample is  0.001063841186116572
#
# The 95% confidence interval is [ 1.9995396991381853 , 2.000818269011221 ]
#
#
# Sample size is  100000
#
# Mean of the sample is  2.000144741807455
#
# Variance of the sample is  0.001056512299981061
#
# The 95% confidence interval is [ 1.999943279710484 , 2.0003462039044266 ]
#
#
# Ratios of the lengths for the 95% confidence intervals are
#
# For sample size =  100 the ratio is 13.292218354666195
#
# For sample size =  1000 the ratio is 13.510142588223971
#
# For sample size =  10000 the ratio is 13.600299686430779
#
# For sample size =  100000 the ratio is 13.575672795088497
